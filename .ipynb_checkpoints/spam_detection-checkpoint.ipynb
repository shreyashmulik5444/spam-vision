# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("datasets/emails.csv")

# %%
df.shape
# Out:
# (5728, 2)

# %%
df.sample(19)
# Out:
#                                                    text  spam
# 5654  Subject: yvan chaxel  your name was listed by ...     0
# 45    Subject: 1000 full color brochures 335  the ts...     1
# 3335  Subject: re : grades  thank you mr . kaminsky ...     0
# 1049  Subject: would you like a $ 250 gas card ?  do...     1
# 372   Subject: offer your clients 11 . 19 %  11 . 19...     1
# 311   Subject: easily lose weight / build muscle / r...     1
# 2003  Subject: purchase of license for software  hel...     0
# 213   Subject: high growth investing for tomorrow  h...     1
# 5687  Subject: flat screens  hello ,  we are still i...     0
# 767   Subject: you don _ t know how to get into sear...     1
# 2276  Subject: re : houston trip  i extended the ren...     0
# 2623  Subject: sabbatical  dr . kaminski :  ?  i had...     0
# 319   Subject: congrats on your approval  we tried t...     1
# 2459  Subject: rab graph  i believe this will be hel...     0
# 149   Subject: good worrk  how to save on aslant you...     1
# 2545  Subject: re : congratulations  thanks .  vince...     0
# 342   Subject: 9 % commission on myg annuities  call...     1
# 5380  Subject: ok -  ok vince - i will stay up tonig...     0
# 3305  Subject: re : avistar training  i will keep yo...     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5728 entries, 0 to 5727
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5728 non-null   object
#  1   spam    5728 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 89.6+ KB

# %%
df.describe()
# Out:
#               spam
# count  5728.000000
# mean      0.238827
# std       0.426404
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df['spam'].value_counts()
# Out:
# spam
# 0    4360
# 1    1368
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# text    0
# spam    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# text    5728
# spam    5728
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(33)

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5695, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.pie( df['spam'].value_counts(), labels=df['spam'].value_counts().index , autopct='%1.2f%%' )
plt.show()

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\shrey\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# aiobotocore                       2.25.0
# aiodns                            3.5.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.13.2
# aioitertools                      0.12.0
# aiosignal                         1.4.0
# alabaster                         0.7.16
# altair                            5.5.0
# anaconda-anon-usage               0.7.5
# anaconda-auth                     0.12.0
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.7.0
# anaconda-client                   1.14.0
# anaconda-navigator                2.7.0
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.10.0
# appdirs                           1.4.4
# archspec                          0.2.5
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              25.1.0
# arrow                             1.4.0
# astroid                           3.3.11
# astropy                           7.1.1
# astropy-iers-data                 0.2025.11.10.0.38.31
# asttokens                         3.0.0
# async-lru                         2.0.5
# asyncssh                          2.21.1
# atomicwrites                      1.4.0
# attrs                             25.4.0
# Automat                           24.8.1
# autopep8                          2.0.4
# babel                             2.17.0
# bcrypt                            5.0.0
# beautifulsoup4                    4.13.5
# binaryornot                       0.4.4
# black                             25.9.0
# bleach                            6.3.0
# blinker                           1.9.0
# bokeh                             3.8.0
# boltons                           25.0.0
# botocore                          1.40.46
# Bottleneck                        1.4.2
# brotlicffi                        1.1.0.0
# cachetools                        5.5.1
# cattrs                            25.3.0
# certifi                           2025.11.12
# cffi                              2.0.0
# chardet                           5.2.0
# charset-normalizer                3.4.4
# click                             8.2.1
# cloudpickle                       3.1.1
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.3
# conda                             25.11.0
# conda-anaconda-telemetry          0.3.0
# conda-anaconda-tos                0.2.2
# conda-build                       25.11.1
# conda-content-trust               0.2.0
# conda_index                       0.7.0
# conda-libmamba-solver             25.11.0
# conda-pack                        0.8.1
# conda-package-handling            2.4.0
# conda_package_streaming           0.12.0
# conda-repo-cli                    1.0.173
# constantly                        23.10.4
# contourpy                         1.3.3
# cookiecutter                      2.6.0
# cryptography                      46.0.3
# cssselect                         1.2.0
# cycler                            0.11.0
# dask                              2025.11.0
# datashader                        0.18.2
# debugpy                           1.8.16
# decorator                         5.2.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.4.0
# distributed                       2025.11.0
# distro                            1.9.0
# docstring-to-markdown             0.17
# docutils                          0.21.2
# et_xmlfile                        2.0.0
# evalidate                         2.0.3
# executing                         2.2.1
# fastjsonschema                    2.21.2
# filelock                          3.20.0
# flake8                            7.1.1
# Flask                             3.1.2
# fonttools                         4.60.1
# frozendict                        2.4.6
# frozenlist                        1.8.0
# fsspec                            2025.10.0
# gitdb                             4.0.12
# GitPython                         3.1.45
# gmpy2                             2.2.1
# greenlet                          3.2.4
# h11                               0.16.0
# h5py                              3.15.1
# HeapDict                          1.0.1
# holoviews                         1.22.0
# html5lib                          1.1
# httpcore                          1.0.9
# httpx                             0.28.1
# hvplot                            0.12.1
# hyperlink                         21.0.0
# idna                              3.11
# ImageIO                           2.37.2
# imagesize                         1.4.1
# imbalanced-learn                  0.14.0
# importlib_metadata                8.7.0
# incremental                       24.7.2
# inflection                        0.5.1
# iniconfig                         2.1.0
# intake                            2.0.8
# intervaltree                      3.1.0
# ipykernel                         6.31.0
# ipympl                            0.9.7
# ipython                           9.7.0
# ipython_pygments_lexers           1.1.1
# ipywidgets                        8.1.7
# isort                             6.1.0
# itemadapter                       0.12.1
# itemloaders                       1.3.2
# itsdangerous                      2.2.0
# jaraco.classes                    3.4.0
# jaraco.context                    0.0.0
# jaraco.functools                  4.1.0
# jedi                              0.19.2
# jellyfish                         1.2.1
# Jinja2                            3.1.6
# jmespath                          1.0.1
# joblib                            1.5.2
# json5                             0.12.1
# jsonpatch                         1.33
# jsonpointer                       3.0.0
# jsonschema                        4.25.0
# jsonschema-specifications         2025.9.1
# jupyter                           1.1.1
# jupyter_client                    8.6.3
# jupyter-console                   6.6.3
# jupyter_core                      5.8.1
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.16.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.4.7
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.28.0
# jupyterlab_widgets                3.0.15
# keyring                           25.7.0
# kiwisolver                        1.4.9
# lazy_loader                       0.4
# lckr_jupyterlab_variableinspector 3.2.4
# libarchive-c                      5.1
# libmambapy                        2.3.2
# lief                              0.16.4
# linkify-it-py                     2.0.3
# llvmlite                          0.45.1
# lmdb                              1.7.5
# locket                            1.0.0
# lsprotocol                        2025.0.0
# lxml                              5.3.0
# lz4                               4.4.5
# Markdown                          3.8
# markdown-it-py                    2.2.0
# MarkupSafe                        3.0.2
# matplotlib                        3.10.6
# matplotlib-inline                 0.2.1
# mccabe                            0.7.0
# mdit-py-plugins                   0.5.0
# mdurl                             0.1.2
# menuinst                          2.4.1
# mistune                           3.1.2
# mkl_fft                           2.1.1
# mkl_random                        1.3.0
# mkl-service                       2.5.2
# more-itertools                    10.8.0
# mpi4py                            4.0.3
# mpmath                            1.3.0
# msgpack                           1.1.1
# multidict                         6.7.0
# multipledispatch                  1.0.0
# mypy                              1.17.1
# mypy_extensions                   1.0.0
# narwhals                          2.7.0
# navigator-updater                 0.6.0
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest_asyncio                      1.6.0
# networkx                          3.5
# nltk                              3.9.2
# notebook                          7.4.5
# notebook_shim                     0.2.4
# numba                             0.62.1
# numexpr                           2.14.1
# numpy                             2.3.5
# numpydoc                          1.9.0
# openpyxl                          3.1.5
# overrides                         7.7.0
# packaging                         25.0
# pandas                            2.3.3
# pandocfilters                     1.5.1
# panel                             1.8.3
# param                             2.3.0
# parsel                            1.10.0
# parso                             0.8.5
# partd                             1.4.2
# pathspec                          0.12.1
# patsy                             1.0.1
# pexpect                           4.9.0
# pickleshare                       0.7.5
# pillow                            12.0.0
# pip                               25.3
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      4.5.0
# plotly                            6.3.0
# pluggy                            1.5.0
# prometheus_client                 0.21.1
# prompt_toolkit                    3.0.52
# propcache                         0.3.1
# Protego                           0.4.0
# protobuf                          5.29.3
# psutil                            7.0.0
# ptyprocess                        0.7.0
# pure_eval                         0.2.3
# py-cpuinfo                        9.0.0
# pyarrow                           21.0.0
# pyasn1                            0.6.1
# pyasn1_modules                    0.4.2
# pycares                           4.10.0
# pycodestyle                       2.12.1
# pycosat                           0.6.6
# pycparser                         2.23
# pyct                              0.6.0
# pycurl                            7.45.7
# pydantic                          2.12.4
# pydantic_core                     2.41.5
# pydantic-settings                 2.12.0
# PyDispatcher                      2.0.7
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.5
# pyflakes                          3.2.0
# PyGithub                          2.8.1
# Pygments                          2.19.2
# PyJWT                             2.10.1
# pylint                            3.3.8
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.6.0
# pyodbc                            5.3.0
# pyOpenSSL                         25.3.0
# pyparsing                         3.2.5
# PyQt5                             5.15.11
# PyQt5_sip                         12.17.0
# PyQtWebEngine                     5.15.7
# PySide6                           6.9.2
# PySocks                           1.7.1
# pytest                            8.4.2
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.0
# python-json-logger                3.2.1
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-ruff                   2.3.0
# python-lsp-server                 1.13.1
# python-slugify                    8.0.4
# pytokens                          0.3.0
# pytoolconfig                      1.2.6
# pytz                              2025.2
# pyuca                             1.2
# pyviz_comms                       3.0.6
# PyWavelets                        1.9.0
# pywin32                           311
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.15
# PyYAML                            6.0.3
# pyzmq                             27.1.0
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.4.0
# qtconsole                         5.7.0
# QtPy                              2.4.3
# queuelib                          1.8.0
# readchar                          4.2.1
# referencing                       0.37.0
# regex                             2025.9.1
# requests                          2.32.5
# requests-file                     2.1.0
# requests-toolbelt                 1.0.0
# rfc3339_validator                 0.1.4
# rfc3986_validator                 0.1.1
# rich                              14.2.0
# roman-numerals-py                 3.1.0
# rope                              1.14.0
# rpds-py                           0.28.0
# rtree                             1.4.1
# ruamel.yaml                       0.18.16
# ruamel.yaml.clib                  0.2.14
# ruamel_yaml_conda                 0.17.21
# ruff                              0.12.0
# s3fs                              2025.10.0
# scikit-image                      0.25.2
# scikit-learn                      1.7.2
# scipy                             1.16.3
# Scrapy                            2.13.3
# seaborn                           0.13.2
# semver                            3.0.4
# Send2Trash                        1.8.2
# service-identity                  24.2.0
# setuptools                        80.9.0
# shellingham                       1.5.4
# shiboken6                         6.9.2
# sip                               6.12.0
# six                               1.17.0
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   3.0.1
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            8.2.3
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# spyder                            6.1.0
# spyder-kernels                    3.1.1
# SQLAlchemy                        2.0.43
# stack_data                        0.6.3
# statsmodels                       0.14.5
# streamlit                         1.51.0
# superqt                           0.7.6
# sympy                             1.14.0
# tables                            3.10.2
# tabulate                          0.9.0
# tblib                             3.1.0
# tenacity                          9.1.2
# terminado                         0.18.1
# text-unidecode                    1.3
# textdistance                      4.6.3
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2025.10.4
# tinycss2                          1.4.0
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.2.1
# tomlkit                           0.13.3
# toolz                             1.0.0
# tornado                           6.5.1
# tqdm                              4.67.1
# traitlets                         5.14.3
# truststore                        0.10.1
# Twisted                           25.5.0
# twisted-iocpsupport               1.0.2
# typer                             0.17.4
# typing_extensions                 4.15.0
# typing-inspection                 0.4.2
# tzdata                            2025.2
# uc-micro-py                       1.0.3
# ujson                             5.11.0
# urllib3                           2.5.0
# w3lib                             2.3.1
# watchdog                          6.0.0
# wcwidth                           0.2.13
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.1.3
# whatthepatch                      1.0.7
# wheel                             0.45.1
# widgetsnbextension                4.0.14
# win_inet_pton                     1.1.0
# winloop                           0.3.1
# wrapt                             1.17.0
# xarray                            2025.10.1
# xgboost                           3.1.2
# xlwings                           0.33.15
# xyzservices                       2025.4.0
# yapf                              0.43.0
# yarl                              1.22.0
# zict                              3.0.0
# zipp                              3.23.0
# zope.interface                    8.0.1
# zstandard                         0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('punkt') #Meaning = Download a pre-built tokenizer model from NLTK
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# Tokenization

# %%
df['char'] = df['text'].apply(len)

# %%
df.head()
# Out:
#                                                 text  spam  char
# 0  Subject: naturally irresistible your corporate...     1  1484
# 1  Subject: the stock trading gunslinger  fanny i...     1   598
# 2  Subject: unbelievable new homes made easy  im ...     1   448
# 3  Subject: 4 color printing special  request add...     1   500
# 4  Subject: do not have money , get software cds ...     1   235

# %%
df['words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#                                                 text  spam  char  words
# 0  Subject: naturally irresistible your corporate...     1  1484    325
# 1  Subject: the stock trading gunslinger  fanny i...     1   598     90
# 2  Subject: unbelievable new homes made easy  im ...     1   448     88
# 3  Subject: 4 color printing special  request add...     1   500     99
# 4  Subject: do not have money , get software cds ...     1   235     53

# %%
df['sentences']=df['text'].apply(lambda x : len( nltk.sent_tokenize(x)))

# %%
df['sentences']
# Out:
# 0       11
# 1        1
# 2        4
# 3        5
# 4        9
#         ..
# 5723     7
# 5724    28
# 5725    30
# 5726     6
# 5727    35
# Name: sentences, Length: 5695, dtype: int64

# %%
df.head()
# Out:
#                                                 text  spam  char  words  \
# 0  Subject: naturally irresistible your corporate...     1  1484    325
# 1  Subject: the stock trading gunslinger  fanny i...     1   598     90
# 2  Subject: unbelievable new homes made easy  im ...     1   448     88
# 3  Subject: 4 color printing special  request add...     1   500     99
# 4  Subject: do not have money , get software cds ...     1   235     53
#
#    sentences
# 0         11
# 1          1
# 2          4
# 3          5
# 4          9

# %%
df.describe()
# Out:
#               spam          char        words    sentences
# count  5695.000000   5695.000000  5695.000000  5695.000000
# mean      0.240211   1558.067076   328.214047    19.462511
# std       0.427249   2047.078711   419.654234    35.981993
# min       0.000000     13.000000     3.000000     1.000000
# 25%       0.000000    508.500000   102.000000     7.000000
# 50%       0.000000    979.000000   211.000000    12.000000
# 75%       0.000000   1893.000000   403.000000    22.000000
# max       1.000000  43952.000000  8479.000000  1565.000000

# %%
#

# %%
df[df['spam']==0][['char','words','sentences']].describe()
# Out:
#                char        words    sentences
# count   4327.000000  4327.000000  4327.000000
# mean    1634.200139   347.283799    19.838225
# std     1965.016383   407.227757    38.124564
# min       13.000000     3.000000     1.000000
# 25%      577.500000   120.000000     7.000000
# 50%     1122.000000   240.000000    13.000000
# 75%     2037.500000   440.500000    22.000000
# max    43952.000000  8479.000000  1565.000000

# %%
df[df['spam']==1][['char' , 'words' , 'sentences']].describe()
# Out:
#                char        words    sentences
# count   1368.000000  1368.000000  1368.000000
# mean    1317.257310   267.896199    18.274123
# std     2271.372893   451.623124    28.130434
# min       18.000000     5.000000     1.000000
# 25%      401.500000    80.000000     6.000000
# 50%      693.500000   141.000000    11.000000
# 75%     1250.250000   252.000000    18.000000
# max    28432.000000  6131.000000   438.000000
